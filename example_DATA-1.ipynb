# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import torch
import pandas as pd
import random
from time import sleep
import gpytorch
from scipy import stats
import scipy
from scipy import stats
from load_datasets import DATA1
from model_train import train_model
from model_utils import *
from evaluation import Evaluation

if torch.cuda.is_available():
  torch.set_default_tensor_type('torch.cuda.FloatTensor')
  print('Use ***GPU***')
  print(torch.cuda.get_device_properties(0).total_memory/1024/1024/1024,'GB')
else:
  print('Use CPU')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Use ***GPU***
# 14.755615234375 GB

# %%
n_iterations = 2000
learning_rate = 1e-3
display_per_iter = 200

dataset = DATA1()
source_size = dataset.source_size
train_size = dataset.train_size
test_size = dataset.test_size
val_size = dataset.val_size

stats_federated = []
for n_sources in [1, 2, 3]: # Replace with [1, 2, 3, 4, 5] for full run
  stats_train_all = []
  stats_test_all = []
  for i, (train, valid, test, contfeats, binfeats) in enumerate(dataset.get_train_valid_test_combined(n_sources)):
    print('***************************************')
    print('***** n_source {},  Replicate #{} *****'.format(n_sources, i+1))
    print('***************************************')

    # Train data
    w, y, y_cf, mu, x = train[0][1].reshape(-1), train[0][2].reshape(-1), train[1][0].reshape(-1),\
                            np.concatenate((train[1][1],train[1][2]),axis=1), train[0][0][:,:]
    N = len(y)
    X = torch.from_numpy(x.reshape(N,-1)).float().to(device)
    Yobs = torch.from_numpy(y.reshape(-1,1)).float().to(device)
    W = torch.from_numpy(w.reshape(-1,1)).float().to(device)
    
    # Test data
    wte, yte, y_cfte, mute, xte = test[0][1].reshape(-1), test[0][2].reshape(-1), test[1][0].reshape(-1), \
                                        np.concatenate((test[1][1],test[1][2]), axis=1), test[0][0][:,:]
    Nte = len(yte)
    Xte = torch.from_numpy(xte.reshape(Nte,-1)).float().to(device)
    Yobste = torch.from_numpy(yte.reshape(-1,1)).float().to(device)
    Wte = torch.from_numpy(wte.reshape(-1,1)).float().to(device)

    # Validation data
    wva, yva, y_cfva, muva, xva = valid[0][1].reshape(-1), valid[0][2].reshape(-1), valid[1][0].reshape(-1), \
                                        np.concatenate((valid[1][1],valid[1][2]), axis=1), valid[0][0][:,:]
    Nva = len(yva)
    Xva = torch.from_numpy(xva.reshape(Nva,-1)).float().to(device)
    Yobsva = torch.from_numpy(yva.reshape(-1,1)).float().to(device)
    Wva = torch.from_numpy(wva.reshape(-1,1)).float().to(device)

    model_server, model_sources = train_model(Yobs=Yobs, X=X, W=W, Yobste=Yobste, Xte=Xte, Wte=Wte, 
                                              y=y, y_cf=y_cf, x=x, w=w, yte=yte, y_cfte=y_cfte, xte=xte, wte=wte,
                                              n_sources=n_sources, train_size=train_size, test_size=test_size,
                                              n_iterations=n_iterations, learning_rate=learning_rate, display_per_iter=display_per_iter,
                                              bin_feats_4moments=True, cont_feats=contfeats, bin_feats=binfeats)

    # EVALUATION
    Ymis_pred_tr = []
    err_ate_source_tr = []
    Ymis_pred_te = []
    err_ate_source_te = []
    for s in range(len(model_sources)):
      idx = range(s*train_size, (s+1)*train_size)
      idxte = range(s*test_size, (s+1)*test_size)
      meanATE_tr, varATE_tr, meanYmis_tr, covYmis_tr = detach_to_numpy(model_sources[s].predictATE(Yobs[idx,:], X[idx,:],
                                                                                                W[idx,:], idx_source=s))
      meanATE_te, varATE_te, meanYmis_te, covYmis_te = detach_to_numpy(model_sources[s].predictATE(Yobste[idxte,:], Xte[idxte,:],
                                                                                                Wte[idxte,:], idx_source=s))
      Ymis_pred_tr.append(meanYmis_tr.reshape(-1))
      Ymis_pred_te.append(meanYmis_te.reshape(-1))

      y0 = (1-w[idx])*y[idx] + w[idx]*y_cf[idx]
      y1 = w[idx]*y[idx] + (1-w[idx])*y_cf[idx]
      y0pred = (1-w[idx])*y[idx] + w[idx]*meanYmis_tr.reshape(-1)
      y1pred = w[idx]*y[idx] + (1-w[idx])*meanYmis_tr.reshape(-1)
      evaluator_tr = Evaluation(m0=y0, m1=y1)
      err_ate_source_tr.append(evaluator_tr.absolute_err_ate(y0pred=y0pred,y1pred=y1pred))

      y0 = (1-wte[idxte])*yte[idxte] + wte[idxte]*y_cfte[idxte]
      y1 = wte[idxte]*yte[idxte] + (1-wte[idxte])*y_cfte[idxte]
      y0pred = (1-wte[idxte])*yte[idxte] + wte[idxte]*meanYmis_te.reshape(-1)
      y1pred = wte[idxte]*yte[idxte] + (1-wte[idxte])*meanYmis_te.reshape(-1)
      evaluator_te = Evaluation(m0=y0, m1=y1)
      err_ate_source_te.append(evaluator_te.absolute_err_ate(y0pred=y0pred,y1pred=y1pred))

    Ymis_pred_tr = np.concatenate(Ymis_pred_tr)
    Ymis_pred_te = np.concatenate(Ymis_pred_te)

    y0 = (1-w)*y + w*y_cf
    y1 = w*y + (1-w)*y_cf
    y0pred = (1-w)*y + w*Ymis_pred_tr.reshape(-1)
    y1pred = w*y + (1-w)*Ymis_pred_tr.reshape(-1)
    evaluator_tr = Evaluation(m0=y0, m1=y1)
    stats_tr = [evaluator_tr.pehe(y0pred=y0pred,y1pred=y1pred),
                evaluator_tr.absolute_err_ate(y0pred=y0pred,y1pred=y1pred),
                np.mean(err_ate_source_tr)]
    stats_train_all.append(stats_tr)
    print('Last result of replicate #{}'.format(i+1))
    print('Train: pehe {}, err_ate {}, err_ate(s) {}'.format(stats_tr[0], stats_tr[1], stats_tr[2]))
    

    y0 = (1-wte)*yte + wte*y_cfte
    y1 = wte*yte + (1-wte)*y_cfte
    y0pred = (1-wte)*yte + wte*Ymis_pred_te.reshape(-1)
    y1pred = wte*yte + (1-wte)*Ymis_pred_te.reshape(-1)
    evaluator_te = Evaluation(m0=y0, m1=y1)
    stats_te = [evaluator_te.pehe(y0pred=y0pred,y1pred=y1pred),
                evaluator_te.absolute_err_ate(y0pred=y0pred,y1pred=y1pred),
                np.mean(err_ate_source_te)]
    stats_test_all.append(stats_te)
    print('Test: pehe {}, err_ate {}, err_ate(s) {}'.format(stats_te[0], stats_te[1], stats_te[2]))

    print('=================================================================')
  print('PERFORMANCE, n_sources {}'.format(n_sources))
  print('Train:', np.mean(stats_train_all,axis=0), stats.sem(stats_train_all,axis=0))
  print('Test:', np.mean(stats_test_all,axis=0), stats.sem(stats_test_all,axis=0))
  stats_federated.append(stats_test_all)
# Out:
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #1 *****
# ***************************************
# Iter: 0
# Train: pehe 6.243826958177213, err_ate 1.3734438532688324, err_ate(s) 1.3734438532688324
# Test: pehe 4.869462311277648, err_ate 1.4093710770479797, err_ate(s) 1.4093710770479797
# =================================================================
# Iter: 200
# Train: pehe 4.982580482675822, err_ate 0.34616036920765003, err_ate(s) 0.34616036920765003
# Test: pehe 4.2409687063238115, err_ate 0.4508216718064255, err_ate(s) 0.4508216718064255
# =================================================================
# Iter: 400
# Train: pehe 5.06260557498888, err_ate 1.5906896744765944, err_ate(s) 1.5906896744765944
# Test: pehe 4.117987384208669, err_ate 0.5599271292251478, err_ate(s) 0.5599271292251478
# =================================================================
# Iter: 600
# Train: pehe 4.646084553064098, err_ate 0.1383325035772618, err_ate(s) 0.1383325035772618
# Test: pehe 4.325239999429508, err_ate 1.3461653904696615, err_ate(s) 1.3461653904696615
# =================================================================
# Iter: 800
# Train: pehe 4.626943127240428, err_ate 0.5135258213155571, err_ate(s) 0.5135258213155571
# Test: pehe 3.9477752784033204, err_ate 0.10196818020412945, err_ate(s) 0.10196818020412945
# =================================================================
# Iter: 1000
# Train: pehe 4.527781612842171, err_ate 0.95654355629304, err_ate(s) 0.95654355629304
# Test: pehe 3.961184676578113, err_ate 0.37022725899231634, err_ate(s) 0.37022725899231634
# =================================================================
# Iter: 1200
# Train: pehe 4.513860161865559, err_ate 0.0919901706375783, err_ate(s) 0.0919901706375783
# Test: pehe 3.908739755883538, err_ate 0.1265023118337305, err_ate(s) 0.1265023118337305
# =================================================================
# Iter: 1400
# Train: pehe 4.578702529460102, err_ate 1.3155867366590206, err_ate(s) 1.3155867366590206
# Test: pehe 3.965424967663559, err_ate 0.9398256292859402, err_ate(s) 0.9398256292859402
# =================================================================
# Iter: 1600
# Train: pehe 4.634952310786286, err_ate 1.8897839243240053, err_ate(s) 1.8897839243240053
# Test: pehe 3.8692358008742707, err_ate 0.48579140859014547, err_ate(s) 0.48579140859014547
# =================================================================
# Iter: 1800
# Train: pehe 4.3588445701678085, err_ate 0.5152630819477739, err_ate(s) 0.5152630819477739
# Test: pehe 3.89252899501233, err_ate 0.46433450067028337, err_ate(s) 0.46433450067028337
# =================================================================
# Last result of replicate #1
# Train: pehe 4.452990874925175, err_ate 0.7532405679025356, err_ate(s) 0.7532405679025356
# Test: pehe 3.989286173581545, err_ate 0.8321472696202865, err_ate(s) 0.8321472696202865
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #2 *****
# ***************************************
# Iter: 0
# Train: pehe 3.9880407904501585, err_ate 1.4550006728941232, err_ate(s) 1.4550006728941232
# Test: pehe 4.548792136369597, err_ate 1.5683962685366284, err_ate(s) 1.5683962685366284
# =================================================================
# Iter: 200
# Train: pehe 3.8277202908240104, err_ate 1.2703497603485017, err_ate(s) 1.2703497603485017
# Test: pehe 4.216676495885992, err_ate 0.6777931442326408, err_ate(s) 0.6777931442326408
# =================================================================
# Iter: 400
# Train: pehe 3.5152863352616452, err_ate 0.12535288005560918, err_ate(s) 0.12535288005560918
# Test: pehe 4.199510199883709, err_ate 0.3469978183394844, err_ate(s) 0.3469978183394844
# =================================================================
# Iter: 600
# Train: pehe 3.576212879019067, err_ate 0.8849658563682465, err_ate(s) 0.8849658563682465
# Test: pehe 3.9552240682868613, err_ate 0.09727963585521326, err_ate(s) 0.09727963585521326
# =================================================================
# Iter: 800
# Train: pehe 3.413842940837058, err_ate 0.5091600186428398, err_ate(s) 0.5091600186428398
# Test: pehe 3.830274095028016, err_ate 0.13081439884324952, err_ate(s) 0.13081439884324952
# =================================================================
# Iter: 1000
# Train: pehe 3.5401388762685766, err_ate 0.9684057336995033, err_ate(s) 0.9684057336995033
# Test: pehe 3.873616404246374, err_ate 1.1247135082112831, err_ate(s) 1.1247135082112831
# =================================================================
# Iter: 1200
# Train: pehe 3.3364896777468944, err_ate 0.44333709388464976, err_ate(s) 0.44333709388464976
# Test: pehe 3.838039821615683, err_ate 0.918017741667483, err_ate(s) 0.918017741667483
# =================================================================
# Iter: 1400
# Train: pehe 3.4106826792229086, err_ate 0.44335328102618154, err_ate(s) 0.44335328102618154
# Test: pehe 3.724737702825328, err_ate 0.5079465694206041, err_ate(s) 0.5079465694206041
# =================================================================
# Iter: 1600
# Train: pehe 3.2772289298135684, err_ate 0.2508474886366753, err_ate(s) 0.2508474886366753
# Test: pehe 3.6320150008626, err_ate 0.2959974373493044, err_ate(s) 0.2959974373493044
# =================================================================
# Iter: 1800
# Train: pehe 3.3993138557757163, err_ate 0.4976999810287385, err_ate(s) 0.4976999810287385
# Test: pehe 3.6892799483995984, err_ate 0.41731283557462073, err_ate(s) 0.41731283557462073
# =================================================================
# Last result of replicate #2
# Train: pehe 3.5643862120633543, err_ate 1.331443536435661, err_ate(s) 1.331443536435661
# Test: pehe 3.8303953456180357, err_ate 0.5013771613641933, err_ate(s) 0.5013771613641933
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #3 *****
# ***************************************
# Iter: 0
# Train: pehe 4.5502493817263785, err_ate 1.5207193133244594, err_ate(s) 1.5207193133244594
# Test: pehe 4.403297968096866, err_ate 1.5116312723418361, err_ate(s) 1.5116312723418361
# =================================================================
# Iter: 200
# Train: pehe 4.645625769202872, err_ate 1.6224338954696735, err_ate(s) 1.6224338954696735
# Test: pehe 4.199051285280476, err_ate 1.5291102628085935, err_ate(s) 1.5291102628085935
# =================================================================
# Iter: 400
# Train: pehe 4.523401856147736, err_ate 0.5931038141260228, err_ate(s) 0.5931038141260228
# Test: pehe 4.113718726558076, err_ate 1.4059180113992742, err_ate(s) 1.4059180113992742
# =================================================================
# Iter: 600
# Train: pehe 5.3279865975576035, err_ate 2.7135217873761732, err_ate(s) 2.7135217873761732
# Test: pehe 4.2012175885758545, err_ate 1.971339183928733, err_ate(s) 1.971339183928733
# =================================================================
# Iter: 800
# Train: pehe 4.424771929471164, err_ate 0.35172017097569275, err_ate(s) 0.35172017097569275
# Test: pehe 4.0638795195741615, err_ate 1.8211528365125544, err_ate(s) 1.8211528365125544
# =================================================================
# Iter: 1000
# Train: pehe 4.70923914015906, err_ate 0.22204312071108068, err_ate(s) 0.22204312071108068
# Test: pehe 3.648574924895233, err_ate 0.10032241967782674, err_ate(s) 0.10032241967782674
# =================================================================
# Iter: 1200
# Train: pehe 4.794605149097312, err_ate 1.5008865185091573, err_ate(s) 1.5008865185091573
# Test: pehe 3.7126580956855606, err_ate 0.48351874091555813, err_ate(s) 0.48351874091555813
# =================================================================
# Iter: 1400
# Train: pehe 5.051110317930199, err_ate 1.7370862455675682, err_ate(s) 1.7370862455675682
# Test: pehe 3.8194097694660134, err_ate 1.0896327900427143, err_ate(s) 1.0896327900427143
# =================================================================
# Iter: 1600
# Train: pehe 4.797849061215643, err_ate 1.5452386118481238, err_ate(s) 1.5452386118481238
# Test: pehe 3.720315854514529, err_ate 1.0820102627861063, err_ate(s) 1.0820102627861063
# =================================================================
# Iter: 1800
# Train: pehe 4.406584095554309, err_ate 0.44531796053148076, err_ate(s) 0.44531796053148076
# Test: pehe 3.664983182584007, err_ate 0.8707384162584653, err_ate(s) 0.8707384162584653
# =================================================================
# Last result of replicate #3
# Train: pehe 4.404946598308031, err_ate 0.09174942106104655, err_ate(s) 0.09174942106104655
# Test: pehe 3.511486322596228, err_ate 0.17672224708387474, err_ate(s) 0.17672224708387474
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #4 *****
# ***************************************
# Iter: 0
# Train: pehe 5.662470068052804, err_ate 0.05408447028190344, err_ate(s) 0.05408447028190344
# Test: pehe 4.544015729754082, err_ate 0.568428341520532, err_ate(s) 0.568428341520532
# =================================================================
# Iter: 200
# Train: pehe 5.042486110314407, err_ate 0.5848047975352363, err_ate(s) 0.5848047975352363
# Test: pehe 4.141206411129608, err_ate 1.2471434082723256, err_ate(s) 1.2471434082723256
# =================================================================
# Iter: 400
# Train: pehe 5.092429435973705, err_ate 1.0889397079399183, err_ate(s) 1.0889397079399183
# Test: pehe 3.825429842190738, err_ate 0.1103224339177884, err_ate(s) 0.1103224339177884
# =================================================================
# Iter: 600
# Train: pehe 4.8414614268871965, err_ate 0.4606321925768302, err_ate(s) 0.4606321925768302
# Test: pehe 3.7198667326891797, err_ate 1.003565289536232, err_ate(s) 1.003565289536232
# =================================================================
# Iter: 800
# Train: pehe 4.8663801710275605, err_ate 0.16087415867537702, err_ate(s) 0.16087415867537702
# Test: pehe 3.536519482062919, err_ate 0.06340485248147942, err_ate(s) 0.06340485248147942
# =================================================================
# Iter: 1000
# Train: pehe 4.688560642717346, err_ate 0.07987031049042526, err_ate(s) 0.07987031049042526
# Test: pehe 3.4471118749499015, err_ate 0.23895509409066817, err_ate(s) 0.23895509409066817
# =================================================================
# Iter: 1200
# Train: pehe 4.623588744436181, err_ate 0.08498852320999362, err_ate(s) 0.08498852320999362
# Test: pehe 3.635960344177181, err_ate 0.8042065307046659, err_ate(s) 0.8042065307046659
# =================================================================
# Iter: 1400
# Train: pehe 4.962618131986297, err_ate 1.9225616783550339, err_ate(s) 1.9225616783550339
# Test: pehe 3.447283456824009, err_ate 0.6348646069882724, err_ate(s) 0.6348646069882724
# =================================================================
# Iter: 1600
# Train: pehe 4.747868273927106, err_ate 0.9491221124580458, err_ate(s) 0.9491221124580458
# Test: pehe 3.383751729633508, err_ate 0.6049832613789001, err_ate(s) 0.6049832613789001
# =================================================================
# Iter: 1800
# Train: pehe 4.657732053332618, err_ate 0.7074749279668885, err_ate(s) 0.7074749279668885
# Test: pehe 3.470422238995993, err_ate 0.7941642636964046, err_ate(s) 0.7941642636964046
# =================================================================
# Last result of replicate #4
# Train: pehe 4.609853254362919, err_ate 0.5077362319180414, err_ate(s) 0.5077362319180414
# Test: pehe 3.5807712447928672, err_ate 0.819608568233094, err_ate(s) 0.819608568233094
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #5 *****
# ***************************************
# Iter: 0
# Train: pehe 4.396423864078438, err_ate 0.8793436861156425, err_ate(s) 0.8793436861156425
# Test: pehe 4.615006951969816, err_ate 1.326064152950249, err_ate(s) 1.326064152950249
# =================================================================
# Iter: 200
# Train: pehe 5.225352576784743, err_ate 2.6774573022245365, err_ate(s) 2.6774573022245365
# Test: pehe 4.516712092041485, err_ate 1.3432089439938664, err_ate(s) 1.3432089439938664
# =================================================================
# Iter: 400
# Train: pehe 4.887072939241279, err_ate 2.181809957039257, err_ate(s) 2.181809957039257
# Test: pehe 4.391069215400274, err_ate 0.8836164434955176, err_ate(s) 0.8836164434955176
# =================================================================
# Iter: 600
# Train: pehe 4.462253400198246, err_ate 0.271542047846417, err_ate(s) 0.271542047846417
# Test: pehe 4.548752022277833, err_ate 1.9242777447578556, err_ate(s) 1.9242777447578556
# =================================================================
# Iter: 800
# Train: pehe 4.6685209534831635, err_ate 0.6642876273511849, err_ate(s) 0.6642876273511849
# Test: pehe 4.1412533949545685, err_ate 0.25974504507637575, err_ate(s) 0.25974504507637575
# =================================================================
# Iter: 1000
# Train: pehe 4.772077167998765, err_ate 0.10276201306591437, err_ate(s) 0.10276201306591437
# Test: pehe 4.5548175384857075, err_ate 1.7419361043948314, err_ate(s) 1.7419361043948314
# =================================================================
# Iter: 1200
# Train: pehe 4.660355825593213, err_ate 1.2581611472486456, err_ate(s) 1.2581611472486456
# Test: pehe 4.297667462470422, err_ate 1.6259439182034243, err_ate(s) 1.6259439182034243
# =================================================================
# Iter: 1400
# Train: pehe 4.353634916609238, err_ate 0.08597856671800219, err_ate(s) 0.08597856671800219
# Test: pehe 4.196305183850791, err_ate 1.3851067360073979, err_ate(s) 1.3851067360073979
# =================================================================
# Iter: 1600
# Train: pehe 4.498496494438982, err_ate 0.6514092814668021, err_ate(s) 0.6514092814668021
# Test: pehe 3.9536700379534064, err_ate 0.3698599727712546, err_ate(s) 0.3698599727712546
# =================================================================
# Iter: 1800
# Train: pehe 4.452372755878268, err_ate 0.4144825729609529, err_ate(s) 0.4144825729609529
# Test: pehe 4.057324567209697, err_ate 0.029588275275111098, err_ate(s) 0.029588275275111098
# =================================================================
# Last result of replicate #5
# Train: pehe 4.609804552533177, err_ate 0.7768787577493987, err_ate(s) 0.7768787577493987
# Test: pehe 4.018487903292985, err_ate 0.11621236729791473, err_ate(s) 0.11621236729791473
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #6 *****
# ***************************************
# Iter: 0
# Train: pehe 4.413422694351191, err_ate 0.4277258498240701, err_ate(s) 0.4277258498240701
# Test: pehe 4.485235674221096, err_ate 0.329182439999281, err_ate(s) 0.329182439999281
# =================================================================
# Iter: 200
# Train: pehe 4.17856145876903, err_ate 0.16499269247245713, err_ate(s) 0.16499269247245713
# Test: pehe 4.290872652729024, err_ate 0.432089593787219, err_ate(s) 0.432089593787219
# =================================================================
# Iter: 400
# Train: pehe 4.094227288529699, err_ate 0.4059898644666679, err_ate(s) 0.4059898644666679
# Test: pehe 4.614608422622756, err_ate 2.4151222957306278, err_ate(s) 2.4151222957306278
# =================================================================
# Iter: 600
# Train: pehe 4.24270018651134, err_ate 1.380135765520812, err_ate(s) 1.380135765520812
# Test: pehe 3.8928848229133086, err_ate 0.5911601688280688, err_ate(s) 0.5911601688280688
# =================================================================
# Iter: 800
# Train: pehe 4.007875338140176, err_ate 0.23438726306152263, err_ate(s) 0.23438726306152263
# Test: pehe 4.088686395000525, err_ate 1.2092411829166778, err_ate(s) 1.2092411829166778
# =================================================================
# Iter: 1000
# Train: pehe 3.9278168960537365, err_ate 0.27584320306968607, err_ate(s) 0.27584320306968607
# Test: pehe 3.886501329545159, err_ate 1.2607453991209905, err_ate(s) 1.2607453991209905
# =================================================================
# Iter: 1200
# Train: pehe 3.897800993765415, err_ate 0.648160338399888, err_ate(s) 0.648160338399888
# Test: pehe 3.7525871662009926, err_ate 0.9884472339066579, err_ate(s) 0.9884472339066579
# =================================================================
# Iter: 1400
# Train: pehe 4.073172471901673, err_ate 1.3031617394108763, err_ate(s) 1.3031617394108763
# Test: pehe 3.6632307756578637, err_ate 0.9767564813563756, err_ate(s) 0.9767564813563756
# =================================================================
# Iter: 1600
# Train: pehe 4.164462284046172, err_ate 1.7117281386275283, err_ate(s) 1.7117281386275283
# Test: pehe 3.602360093038193, err_ate 0.19947875017049754, err_ate(s) 0.19947875017049754
# =================================================================
# Iter: 1800
# Train: pehe 4.021700796038826, err_ate 1.2687546420116416, err_ate(s) 1.2687546420116416
# Test: pehe 3.817775228750721, err_ate 0.9398078650955436, err_ate(s) 0.9398078650955436
# =================================================================
# Last result of replicate #6
# Train: pehe 3.750079084191587, err_ate 0.25421428442191996, err_ate(s) 0.25421428442191996
# Test: pehe 3.9192413305541693, err_ate 1.527801009224354, err_ate(s) 1.527801009224354
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #7 *****
# ***************************************
# Iter: 0
# Train: pehe 5.380783406206236, err_ate 1.8626740266024477, err_ate(s) 1.8626740266024477
# Test: pehe 4.648296667573949, err_ate 1.6976856356007466, err_ate(s) 1.6976856356007466
# =================================================================
# Iter: 200
# Train: pehe 5.046208067211545, err_ate 2.7958949613929382, err_ate(s) 2.7958949613929382
# Test: pehe 4.423745594710405, err_ate 1.7421121509953996, err_ate(s) 1.7421121509953996
# =================================================================
# Iter: 400
# Train: pehe 3.5866936205043083, err_ate 0.7656013341606251, err_ate(s) 0.7656013341606251
# Test: pehe 3.6215558652380277, err_ate 0.8975413107369097, err_ate(s) 0.8975413107369097
# =================================================================
# Iter: 600
# Train: pehe 3.818734452002322, err_ate 1.7579947133720513, err_ate(s) 1.7579947133720513
# Test: pehe 3.799010507363301, err_ate 1.7469995215743446, err_ate(s) 1.7469995215743446
# =================================================================
# Iter: 800
# Train: pehe 3.516646012594968, err_ate 0.9760785799086684, err_ate(s) 0.9760785799086684
# Test: pehe 4.25354029008272, err_ate 2.2981391107600864, err_ate(s) 2.2981391107600864
# =================================================================
# Iter: 1000
# Train: pehe 3.4360478719161653, err_ate 0.8701376785696149, err_ate(s) 0.8701376785696149
# Test: pehe 3.322478434394103, err_ate 0.6567824646395379, err_ate(s) 0.6567824646395379
# =================================================================
# Iter: 1200
# Train: pehe 3.469603909841, err_ate 0.1350838234662417, err_ate(s) 0.1350838234662417
# Test: pehe 3.350939633610594, err_ate 0.7886055399516427, err_ate(s) 0.7886055399516427
# =================================================================
# Iter: 1400
# Train: pehe 3.308394108181948, err_ate 0.486318564897835, err_ate(s) 0.486318564897835
# Test: pehe 3.798533189274632, err_ate 1.780594302114946, err_ate(s) 1.780594302114946
# =================================================================
# Iter: 1600
# Train: pehe 3.445057920010448, err_ate 1.0794965107380756, err_ate(s) 1.0794965107380756
# Test: pehe 3.18059920925563, err_ate 0.15918097382191188, err_ate(s) 0.15918097382191188
# =================================================================
# Iter: 1800
# Train: pehe 3.2631657407319437, err_ate 0.09302460920208744, err_ate(s) 0.09302460920208744
# Test: pehe 3.2139955306411903, err_ate 0.5322813973418347, err_ate(s) 0.5322813973418347
# =================================================================
# Last result of replicate #7
# Train: pehe 3.2722169851962284, err_ate 0.08718494463568849, err_ate(s) 0.08718494463568849
# Test: pehe 3.4537098074601844, err_ate 1.3167388264738362, err_ate(s) 1.3167388264738362
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #8 *****
# ***************************************
# Iter: 0
# Train: pehe 6.103803013902531, err_ate 3.0831970433455256, err_ate(s) 3.0831970433455256
# Test: pehe 4.410804232487842, err_ate 0.16118805226140853, err_ate(s) 0.16118805226140853
# =================================================================
# Iter: 200
# Train: pehe 4.480657855096614, err_ate 0.18428287892301443, err_ate(s) 0.18428287892301443
# Test: pehe 4.261300014844553, err_ate 1.4183310350586154, err_ate(s) 1.4183310350586154
# =================================================================
# Iter: 400
# Train: pehe 4.068123480981458, err_ate 1.2476764497284143, err_ate(s) 1.2476764497284143
# Test: pehe 3.8684289990692355, err_ate 0.987885056430652, err_ate(s) 0.987885056430652
# =================================================================
# Iter: 600
# Train: pehe 3.9067966095687106, err_ate 0.43692224086563236, err_ate(s) 0.43692224086563236
# Test: pehe 3.686861174840723, err_ate 0.560562417820105, err_ate(s) 0.560562417820105
# =================================================================
# Iter: 800
# Train: pehe 3.8636576987072773, err_ate 0.22932096318642703, err_ate(s) 0.22932096318642703
# Test: pehe 3.6002267061022017, err_ate 0.6062032924809329, err_ate(s) 0.6062032924809329
# =================================================================
# Iter: 1000
# Train: pehe 4.185295596428562, err_ate 1.4859358284000603, err_ate(s) 1.4859358284000603
# Test: pehe 3.5288703386304743, err_ate 0.17911687759649553, err_ate(s) 0.17911687759649553
# =================================================================
# Iter: 1200
# Train: pehe 3.88118037337743, err_ate 0.07105742448310481, err_ate(s) 0.07105742448310481
# Test: pehe 3.908441829914306, err_ate 1.6550005120729945, err_ate(s) 1.6550005120729945
# =================================================================
# Iter: 1400
# Train: pehe 3.912144947667155, err_ate 0.9423751443747723, err_ate(s) 0.9423751443747723
# Test: pehe 3.4662477214266256, err_ate 0.344918999324477, err_ate(s) 0.344918999324477
# =================================================================
# Iter: 1600
# Train: pehe 4.999414745445797, err_ate 2.828974626225635, err_ate(s) 2.828974626225635
# Test: pehe 3.5552633529800954, err_ate 0.32224621165746103, err_ate(s) 0.32224621165746103
# =================================================================
# Iter: 1800
# Train: pehe 3.6591245565316854, err_ate 0.785799739075109, err_ate(s) 0.785799739075109
# Test: pehe 3.478539181444178, err_ate 0.6568577070039872, err_ate(s) 0.6568577070039872
# =================================================================
# Last result of replicate #8
# Train: pehe 3.8007123705721826, err_ate 0.23952674285809605, err_ate(s) 0.23952674285809605
# Test: pehe 3.5872353887021577, err_ate 0.05803258688748758, err_ate(s) 0.05803258688748758
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #9 *****
# ***************************************
# Iter: 0
# Train: pehe 5.355062643768125, err_ate 0.6788816489689389, err_ate(s) 0.6788816489689389
# Test: pehe 5.150592946210361, err_ate 1.3750609807147658, err_ate(s) 1.3750609807147658
# =================================================================
# Iter: 200
# Train: pehe 4.955178527211925, err_ate 1.3377480310536585, err_ate(s) 1.3377480310536585
# Test: pehe 4.247707653820532, err_ate 0.732537473919131, err_ate(s) 0.732537473919131
# =================================================================
# Iter: 400
# Train: pehe 4.544856808360937, err_ate 0.08400960903990644, err_ate(s) 0.08400960903990644
# Test: pehe 3.840560853284685, err_ate 0.04827925770314223, err_ate(s) 0.04827925770314223
# =================================================================
# Iter: 600
# Train: pehe 4.845792249666105, err_ate 1.7737630788646974, err_ate(s) 1.7737630788646974
# Test: pehe 4.520515897140735, err_ate 2.3443556722882555, err_ate(s) 2.3443556722882555
# =================================================================
# Iter: 800
# Train: pehe 4.218529794087741, err_ate 0.10180196929347138, err_ate(s) 0.10180196929347138
# Test: pehe 3.6439741825621064, err_ate 0.18690929052359995, err_ate(s) 0.18690929052359995
# =================================================================
# Iter: 1000
# Train: pehe 4.179381232838746, err_ate 0.4292359336055479, err_ate(s) 0.4292359336055479
# Test: pehe 3.692828345458388, err_ate 0.7310952162897484, err_ate(s) 0.7310952162897484
# =================================================================
# Iter: 1200
# Train: pehe 4.166961932404137, err_ate 0.2600734883211889, err_ate(s) 0.2600734883211889
# Test: pehe 3.667722616154461, err_ate 0.7977988245696268, err_ate(s) 0.7977988245696268
# =================================================================
# Iter: 1400
# Train: pehe 4.104178266464451, err_ate 0.1663679391480646, err_ate(s) 0.1663679391480646
# Test: pehe 3.778360811118803, err_ate 1.2228842848660355, err_ate(s) 1.2228842848660355
# =================================================================
# Iter: 1600
# Train: pehe 4.083387436896678, err_ate 0.4996368108354845, err_ate(s) 0.4996368108354845
# Test: pehe 3.6187544202418906, err_ate 0.6473430223375998, err_ate(s) 0.6473430223375998
# =================================================================
# Iter: 1800
# Train: pehe 4.487532468070916, err_ate 1.9547253217958251, err_ate(s) 1.9547253217958251
# Test: pehe 3.7426790677403425, err_ate 0.23549384271412055, err_ate(s) 0.23549384271412055
# =================================================================
# Last result of replicate #9
# Train: pehe 4.206350145135072, err_ate 0.7504013444148341, err_ate(s) 0.7504013444148341
# Test: pehe 3.6381520463194157, err_ate 0.3040981171463939, err_ate(s) 0.3040981171463939
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 1,  Replicate #10 *****
# ***************************************
# Iter: 0
# Train: pehe 5.338430145783483, err_ate 2.206270438000059, err_ate(s) 2.206270438000059
# Test: pehe 4.561344530625516, err_ate 0.7431723110642282, err_ate(s) 0.7431723110642282
# =================================================================
# Iter: 200
# Train: pehe 4.374151403671047, err_ate 0.3365666477526186, err_ate(s) 0.3365666477526186
# Test: pehe 4.367955521616804, err_ate 0.4445934217044233, err_ate(s) 0.4445934217044233
# =================================================================
# Iter: 400
# Train: pehe 4.175113132902572, err_ate 0.07637062801470806, err_ate(s) 0.07637062801470806
# Test: pehe 4.099654495415989, err_ate 1.3178840752921652, err_ate(s) 1.3178840752921652
# =================================================================
# Iter: 600
# Train: pehe 4.440954385136115, err_ate 1.3595008434499258, err_ate(s) 1.3595008434499258
# Test: pehe 3.901508406901741, err_ate 0.6334007449619469, err_ate(s) 0.6334007449619469
# =================================================================
# Iter: 800
# Train: pehe 4.247779564987982, err_ate 0.49865019941279876, err_ate(s) 0.49865019941279876
# Test: pehe 3.8096268005853773, err_ate 0.027226776178621015, err_ate(s) 0.027226776178621015
# =================================================================
# Iter: 1000
# Train: pehe 4.344769759186076, err_ate 1.2230153744066714, err_ate(s) 1.2230153744066714
# Test: pehe 3.8210745693376986, err_ate 0.4777138476981694, err_ate(s) 0.4777138476981694
# =================================================================
# Iter: 1200
# Train: pehe 4.397619032950188, err_ate 1.1295209674681181, err_ate(s) 1.1295209674681181
# Test: pehe 3.7915783125334466, err_ate 0.31165280282094365, err_ate(s) 0.31165280282094365
# =================================================================
# Iter: 1400
# Train: pehe 4.3173045853921295, err_ate 0.7008238952005861, err_ate(s) 0.7008238952005861
# Test: pehe 3.9716073865555592, err_ate 0.34529026394266327, err_ate(s) 0.34529026394266327
# =================================================================
# Iter: 1600
# Train: pehe 4.2607300574625615, err_ate 0.18809244872579578, err_ate(s) 0.18809244872579578
# Test: pehe 4.562918119789515, err_ate 2.1867492775646458, err_ate(s) 2.1867492775646458
# =================================================================
# Iter: 1800
# Train: pehe 4.280747785532318, err_ate 0.44284064249644217, err_ate(s) 0.44284064249644217
# Test: pehe 3.833560239162523, err_ate 0.505428637194396, err_ate(s) 0.505428637194396
# =================================================================
# Last result of replicate #10
# Train: pehe 4.277206570985212, err_ate 0.12027733632872062, err_ate(s) 0.12027733632872062
# Test: pehe 3.7748068975193405, err_ate 0.4324506874151869, err_ate(s) 0.4324506874151869
# =================================================================
# PERFORMANCE, n_sources 1
# Train: [4.09485466 0.49126532 0.49126532] [0.14772416 0.12925512 0.12925512]
# Test: [3.73035725 0.60851888 0.60851888] [0.06442256 0.16014661 0.16014661]
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 2,  Replicate #1 *****
# ***************************************
# Iter: 0
# Train: pehe 5.065889686027402, err_ate 0.5335668111108028, err_ate(s) 1.2949858559310052
# Test: pehe 4.439096690511503, err_ate 0.37966613431751206, err_ate(s) 0.3820204297149647
# =================================================================
# Iter: 200
# Train: pehe 4.632110994916236, err_ate 1.3250146197043144, err_ate(s) 1.3250146197043144
# Test: pehe 4.132006851407962, err_ate 0.13162432273208613, err_ate(s) 0.48928994023312994
# =================================================================
# Iter: 400
# Train: pehe 3.7340727589122253, err_ate 0.8521071687601292, err_ate(s) 0.8521071687601292
# Test: pehe 3.5991308317757387, err_ate 1.2557840819602442, err_ate(s) 1.2557840819602446
# =================================================================
# Iter: 600
# Train: pehe 3.30133189587545, err_ate 1.1302788101397239, err_ate(s) 1.1302788101397239
# Test: pehe 3.0321879810540664, err_ate 0.1316808909614432, err_ate(s) 0.3698151261546997
# =================================================================
# Iter: 800
# Train: pehe 3.2051869224218987, err_ate 0.6524960139654361, err_ate(s) 1.170676991975346
# Test: pehe 2.907380443141128, err_ate 0.6103914369816924, err_ate(s) 0.6103914369816926
# =================================================================
# Iter: 1000
# Train: pehe 3.3406759095480054, err_ate 1.6056873350385363, err_ate(s) 1.6056873350385361
# Test: pehe 2.851767804726955, err_ate 0.6102882883728006, err_ate(s) 0.6102882883728009
# =================================================================
# Iter: 1200
# Train: pehe 2.8770876529241054, err_ate 0.35733137098329415, err_ate(s) 0.5028829123437788
# Test: pehe 2.7522417353411863, err_ate 0.06613719388794004, err_ate(s) 0.5810668508884997
# =================================================================
# Iter: 1400
# Train: pehe 2.7245775351675317, err_ate 0.19043006109816674, err_ate(s) 0.7834180534243967
# Test: pehe 2.6237877638812894, err_ate 0.12633838552848387, err_ate(s) 0.12633838552848342
# =================================================================
# Iter: 1600
# Train: pehe 3.001574243480688, err_ate 1.1786208735666954, err_ate(s) 1.1786208735666954
# Test: pehe 2.7518012856347815, err_ate 0.6871506338258135, err_ate(s) 0.687150633825814
# =================================================================
# Iter: 1800
# Train: pehe 2.70349764935811, err_ate 0.6922646491714037, err_ate(s) 0.8814837513476996
# Test: pehe 2.620777500174296, err_ate 0.11698967522384973, err_ate(s) 0.26724166155551565
# =================================================================
# Last result of replicate #1
# Train: pehe 2.6863434973958396, err_ate 0.35443144050615194, err_ate(s) 0.35443144050615194
# Test: pehe 2.774120593384257, err_ate 0.5145336760939743, err_ate(s) 0.7155669092693036
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 2,  Replicate #2 *****
# ***************************************
# Iter: 0
# Train: pehe 4.10376639816259, err_ate 0.03907218573162763, err_ate(s) 0.992363589796628
# Test: pehe 4.677517639012155, err_ate 1.1872383814974583, err_ate(s) 1.1872383814974583
# =================================================================
# Iter: 200
# Train: pehe 3.5452702440628556, err_ate 0.6374551131435258, err_ate(s) 1.2793234474403608
# Test: pehe 3.826089860834965, err_ate 0.7074617419416613, err_ate(s) 0.7074617419416613
# =================================================================
# Iter: 400
# Train: pehe 3.182951085524521, err_ate 0.04769470474203641, err_ate(s) 1.0872573911206977
# Test: pehe 3.3706241060218107, err_ate 0.11358694745305797, err_ate(s) 0.11358694745305808
# =================================================================
# Iter: 600
# Train: pehe 2.9177302696896206, err_ate 0.7789747288591643, err_ate(s) 0.778974728859164
# Test: pehe 3.3034816935467166, err_ate 0.054759394056652866, err_ate(s) 0.35901838367429545
# =================================================================
# Iter: 800
# Train: pehe 2.764671870342694, err_ate 0.7867002751537184, err_ate(s) 0.7867002751537188
# Test: pehe 3.20599018778297, err_ate 0.38818006076674094, err_ate(s) 0.38818006076674105
# =================================================================
# Iter: 1000
# Train: pehe 2.5701342770556166, err_ate 0.3432806476809602, err_ate(s) 0.4636515750182616
# Test: pehe 3.0757287603398136, err_ate 0.09211276900439991, err_ate(s) 0.5323743458732003
# =================================================================
# Iter: 1200
# Train: pehe 2.5428690540222605, err_ate 0.2654850910462958, err_ate(s) 0.26548509104629614
# Test: pehe 2.9371994771869754, err_ate 0.11605744732706591, err_ate(s) 0.4577849177164732
# =================================================================
# Iter: 1400
# Train: pehe 2.5352034035551956, err_ate 0.11459740073899227, err_ate(s) 0.7447066561686051
# Test: pehe 3.077243783057555, err_ate 0.14298350417061778, err_ate(s) 1.0526347956260893
# =================================================================
# Iter: 1600
# Train: pehe 2.573683868730991, err_ate 0.7106936537615438, err_ate(s) 0.7106936537615434
# Test: pehe 2.953561588088168, err_ate 0.05669555450867736, err_ate(s) 0.38107142400552485
# =================================================================
# Iter: 1800
# Train: pehe 2.50085988574183, err_ate 0.1398345809570929, err_ate(s) 0.8894211828155267
# Test: pehe 2.9502202958922203, err_ate 0.7051574676882455, err_ate(s) 0.7051574676882455
# =================================================================
# Last result of replicate #2
# Train: pehe 2.3651692842378287, err_ate 0.5356284085520129, err_ate(s) 0.5356284085520133
# Test: pehe 2.8626743962377215, err_ate 0.004674226710168483, err_ate(s) 0.6137344789738399
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 2,  Replicate #3 *****
# ***************************************
# Iter: 0
# Train: pehe 4.184615518859134, err_ate 1.113939338095606, err_ate(s) 1.1139393380956055
# Test: pehe 4.335914666411713, err_ate 0.25795554545579913, err_ate(s) 0.25795554545579924
# =================================================================
# Iter: 200
# Train: pehe 3.647561785137797, err_ate 0.8328036617374712, err_ate(s) 0.8328036617374714
# Test: pehe 3.5615611184845006, err_ate 0.7055016737469498, err_ate(s) 0.7055016737469495
# =================================================================
# Iter: 400
# Train: pehe 2.881819320790195, err_ate 0.5859338487012977, err_ate(s) 0.6022733566846334
# Test: pehe 2.7985646999384297, err_ate 0.39073066782588417, err_ate(s) 0.39073066782588367
# =================================================================
# Iter: 600
# Train: pehe 2.5512723465718437, err_ate 0.07704333836945843, err_ate(s) 0.14203352450098786
# Test: pehe 2.7822612096680506, err_ate 0.6827417102832966, err_ate(s) 0.6827417102832964
# =================================================================
# Iter: 800
# Train: pehe 2.63022526996726, err_ate 0.6758389701767558, err_ate(s) 0.6758389701767561
# Test: pehe 2.722034935965015, err_ate 0.7642729605306897, err_ate(s) 0.7642729605306894
# =================================================================
# Iter: 1000
# Train: pehe 2.96910480528459, err_ate 1.444852885387718, err_ate(s) 1.4448528853877183
# Test: pehe 2.7527684349230186, err_ate 1.2853285416118403, err_ate(s) 1.28532854161184
# =================================================================
# Iter: 1200
# Train: pehe 2.5099392128460676, err_ate 0.18429875277715868, err_ate(s) 0.5048418978538
# Test: pehe 2.3665794859271285, err_ate 0.18326179666657438, err_ate(s) 0.18326179666657405
# =================================================================
# Iter: 1400
# Train: pehe 2.5733236033841527, err_ate 0.2654162503852242, err_ate(s) 0.7984141881827632
# Test: pehe 2.327298528038229, err_ate 0.03701613202139642, err_ate(s) 0.38779593951726876
# =================================================================
# Iter: 1600
# Train: pehe 2.685735304359535, err_ate 0.9868188019915217, err_ate(s) 0.9868188019915219
# Test: pehe 2.464623953882951, err_ate 0.25798103622966284, err_ate(s) 0.9574895739968294
# =================================================================
# Iter: 1800
# Train: pehe 2.5914553411503567, err_ate 0.62048926153022, err_ate(s) 0.7842497786198179
# Test: pehe 2.3754312344631505, err_ate 0.3119872136380295, err_ate(s) 0.6261554450357776
# =================================================================
# Last result of replicate #3
# Train: pehe 2.417623006091487, err_ate 0.35215772972243964, err_ate(s) 0.35215772972243975
# Test: pehe 2.313205171323455, err_ate 0.0686365280931247, err_ate(s) 0.31855112780836115
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 2,  Replicate #4 *****
# ***************************************
# Iter: 0
# Train: pehe 5.8827369264688505, err_ate 3.235112511825385, err_ate(s) 3.2351125118253847
# Test: pehe 5.26912625227321, err_ate 2.761210750425028, err_ate(s) 2.761210750425028
# =================================================================
# Iter: 200
# Train: pehe 3.763897968270435, err_ate 1.3349490912748598, err_ate(s) 1.3349490912748596
# Test: pehe 3.4207822425926424, err_ate 0.405109247188301, err_ate(s) 0.40510924718830077
# =================================================================
# Iter: 400
# Train: pehe 2.817812560918263, err_ate 0.23802148566824433, err_ate(s) 0.23802148566824433
# Test: pehe 3.034907783961367, err_ate 1.0926502340648971, err_ate(s) 1.092650234064897
# =================================================================
# Iter: 600
# Train: pehe 3.0172570981646722, err_ate 1.5591411351157451, err_ate(s) 1.5591411351157447
# Test: pehe 2.6870710861679536, err_ate 0.7013024832890424, err_ate(s) 0.713971125895041
# =================================================================
# Iter: 800
# Train: pehe 2.6470542521871034, err_ate 0.8301068500919365, err_ate(s) 0.8301068500919364
# Test: pehe 2.5321529319789504, err_ate 0.05161801171807112, err_ate(s) 0.8470415997572392
# =================================================================
# Iter: 1000
# Train: pehe 2.53518879994467, err_ate 0.04306953071859709, err_ate(s) 0.3497190184489126
# Test: pehe 2.4186872978893024, err_ate 0.30966389131330674, err_ate(s) 0.3096638913133065
# =================================================================
# Iter: 1200
# Train: pehe 2.595943244013237, err_ate 0.054281902110772995, err_ate(s) 0.05428190211077266
# Test: pehe 2.593174691671454, err_ate 0.5066239635246352, err_ate(s) 0.506623963524635
# =================================================================
# Iter: 1400
# Train: pehe 2.488689529611086, err_ate 0.3157445992646837, err_ate(s) 0.31574459926468357
# Test: pehe 2.3273469103734308, err_ate 0.10210343731841887, err_ate(s) 0.3504958312552612
# =================================================================
# Iter: 1600
# Train: pehe 2.515259015557569, err_ate 0.023745977755067482, err_ate(s) 0.45914868527727676
# Test: pehe 2.386205370025462, err_ate 0.3915790255509626, err_ate(s) 0.39157902555096236
# =================================================================
# Iter: 1800
# Train: pehe 2.723589669397113, err_ate 0.9019839835422014, err_ate(s) 0.9938180912442741
# Test: pehe 2.335871185956818, err_ate 0.5174905095374353, err_ate(s) 0.5174905095374349
# =================================================================
# Last result of replicate #4
# Train: pehe 2.459464706200836, err_ate 0.22161133499127872, err_ate(s) 0.5390218788601224
# Test: pehe 2.393648283629161, err_ate 0.5022726063487404, err_ate(s) 0.5022726063487406
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 2,  Replicate #5 *****
# ***************************************
# Iter: 0
# Train: pehe 5.36054241378879, err_ate 0.46082993829200775, err_ate(s) 1.8404823883885157
# Test: pehe 4.7238637251709354, err_ate 1.4072037335052368, err_ate(s) 1.4072037335052368
# =================================================================
# Iter: 200
# Train: pehe 4.689098164089264, err_ate 0.2530864592125006, err_ate(s) 1.3453708498069656
# Test: pehe 4.717899416394988, err_ate 1.393237861133583, err_ate(s) 1.3932378611335827
# =================================================================
# Iter: 400
# Train: pehe 3.9967799910570556, err_ate 0.313253219365578, err_ate(s) 0.31325321936557804
# Test: pehe 4.0177764883947, err_ate 0.0780885007652583, err_ate(s) 0.1494319133944571
# =================================================================
# Iter: 600
# Train: pehe 3.9730004263131717, err_ate 0.7165308930208274, err_ate(s) 0.9312729360052955
# Test: pehe 3.7576769835092856, err_ate 0.25973955963960527, err_ate(s) 0.2597395596396051
# =================================================================
# Iter: 800
# Train: pehe 3.8287036806670067, err_ate 0.3568979274998119, err_ate(s) 1.1885548613110197
# Test: pehe 3.7071118486044154, err_ate 0.6358571670133496, err_ate(s) 0.6358571670133495
# =================================================================
# Iter: 1000
# Train: pehe 3.796232462341343, err_ate 0.24853800222699723, err_ate(s) 1.2702602963225555
# Test: pehe 3.5631643489921556, err_ate 0.5730087685954378, err_ate(s) 0.660919816169573
# =================================================================
# Iter: 1200
# Train: pehe 3.5959104202787344, err_ate 0.45879823448558527, err_ate(s) 0.5673931202182185
# Test: pehe 3.6666765983782788, err_ate 1.272435392594833, err_ate(s) 1.2724353925948328
# =================================================================
# Iter: 1400
# Train: pehe 3.4726623644416716, err_ate 0.6465474839737005, err_ate(s) 0.6465474839737008
# Test: pehe 3.4686804828651763, err_ate 0.9983501639789691, err_ate(s) 0.998350163978969
# =================================================================
# Iter: 1600
# Train: pehe 3.3455563738117364, err_ate 0.23268520196477677, err_ate(s) 0.38044579333454476
# Test: pehe 3.2922187831091145, err_ate 0.27265692392226537, err_ate(s) 0.2726569239222657
# =================================================================
# Iter: 1800
# Train: pehe 3.498222957238203, err_ate 0.4528176817526408, err_ate(s) 0.9531557011494052
# Test: pehe 3.454870871804517, err_ate 0.7306057216520212, err_ate(s) 0.7306057216520211
# =================================================================
# Last result of replicate #5
# Train: pehe 3.3383134717505336, err_ate 0.42548634642313027, err_ate(s) 0.42548634642313043
# Test: pehe 3.234698864748757, err_ate 0.5362718573344916, err_ate(s) 0.5362718573344913
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 2,  Replicate #6 *****
# ***************************************
# Iter: 0
# Train: pehe 4.632592277480329, err_ate 0.8568473280670523, err_ate(s) 1.369522656621682
# Test: pehe 4.578208813022948, err_ate 0.8342323428253188, err_ate(s) 0.8342323428253187
# =================================================================
# Iter: 200
# Train: pehe 4.244054872151729, err_ate 0.4142751655371455, err_ate(s) 2.187936522774669
# Test: pehe 3.9219166013626863, err_ate 0.7121241932399942, err_ate(s) 0.7121241932399942
# =================================================================
# Iter: 400
# Train: pehe 3.3046850013329285, err_ate 0.7364137421564727, err_ate(s) 0.7364137421564727
# Test: pehe 3.4734672707034826, err_ate 0.32978689383339155, err_ate(s) 0.3297868938333915
# =================================================================
# Iter: 600
# Train: pehe 3.2148418766236455, err_ate 0.8727255401371449, err_ate(s) 0.872725540137145
# Test: pehe 3.184284719339645, err_ate 0.32990946641662267, err_ate(s) 0.32990946641662255
# =================================================================
# Iter: 800
# Train: pehe 2.670081997467173, err_ate 0.004086910636868835, err_ate(s) 0.006714027076689111
# Test: pehe 3.09004574677754, err_ate 0.4141296605295448, err_ate(s) 0.8703421293041602
# =================================================================
# Iter: 1000
# Train: pehe 2.729400520988978, err_ate 0.9222371194714276, err_ate(s) 0.9222371194714276
# Test: pehe 3.248937190460374, err_ate 0.6067695409766958, err_ate(s) 1.0110274398000085
# =================================================================
# Iter: 1200
# Train: pehe 2.6858565672616246, err_ate 1.0158028848858145, err_ate(s) 1.0158028848858147
# Test: pehe 2.909032053547016, err_ate 0.5029207436642558, err_ate(s) 0.5029207436642558
# =================================================================
# Iter: 1400
# Train: pehe 2.67290095155072, err_ate 0.5973987964151829, err_ate(s) 0.597398796415183
# Test: pehe 2.8464356600007905, err_ate 0.23663676031140768, err_ate(s) 0.4383056584682973
# =================================================================
# Iter: 1600
# Train: pehe 2.6645621966715423, err_ate 0.8418873578698902, err_ate(s) 0.8418873578698902
# Test: pehe 3.096251581955775, err_ate 1.4023168474401466, err_ate(s) 1.4023168474401464
# =================================================================
# Iter: 1800
# Train: pehe 2.607944802199761, err_ate 0.6623853701709241, err_ate(s) 0.6623853701709242
# Test: pehe 2.6785067637187625, err_ate 0.14293362294361311, err_ate(s) 0.17751568645780935
# =================================================================
# Last result of replicate #6
# Train: pehe 2.4185569444368085, err_ate 0.23426357638254447, err_ate(s) 0.6420613097029649
# Test: pehe 2.9782572688126296, err_ate 0.5701340794089642, err_ate(s) 0.9646504980976799
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 2,  Replicate #7 *****
# ***************************************
# Iter: 0
# ...
# =================================================================
# Iter: 1600
# Train: pehe 2.891481483936148, err_ate 0.2557046536675772, err_ate(s) 0.3011606629697135
# Test: pehe 2.984358956833774, err_ate 0.9095169224479636, err_ate(s) 0.9095169224479633
# =================================================================
# Iter: 1800
# Train: pehe 3.0176195106460435, err_ate 0.8167272063167574, err_ate(s) 0.8167272063167573
# Test: pehe 3.132420950409146, err_ate 1.3906540452615193, err_ate(s) 1.3906540452615193
# =================================================================
# Last result of replicate #5
# Train: pehe 3.0448913031995426, err_ate 0.3013313553286907, err_ate(s) 1.0839032800627402
# Test: pehe 2.69796307687241, err_ate 0.43599682651371896, err_ate(s) 0.4359968265137188
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 3,  Replicate #6 *****
# ***************************************
# Iter: 0
# Train: pehe 4.7682015010436425, err_ate 1.3731067872202418, err_ate(s) 1.4205389232107812
# Test: pehe 4.751773903194338, err_ate 1.6089836767272487, err_ate(s) 1.6089836767272485
# =================================================================
# Iter: 200
# Train: pehe 3.536041653281927, err_ate 0.1564812203341699, err_ate(s) 0.524069784043711
# Test: pehe 3.3789336679344717, err_ate 0.2271341510863889, err_ate(s) 0.34692219897323534
# =================================================================
# Iter: 400
# Train: pehe 3.5208750679862404, err_ate 0.7068076496726298, err_ate(s) 0.7068076496726295
# Test: pehe 3.357779638380956, err_ate 0.44162799532422814, err_ate(s) 0.5271499531155305
# =================================================================
# Iter: 600
# Train: pehe 3.186840766251349, err_ate 1.3981969551587083, err_ate(s) 1.3981969551587081
# Test: pehe 3.0607141976516186, err_ate 1.2115111964848937, err_ate(s) 1.211511196484894
# =================================================================
# Iter: 800
# Train: pehe 2.6934392468744566, err_ate 0.37057460518866536, err_ate(s) 0.5916648878449019
# Test: pehe 2.8327038604161645, err_ate 0.5695896776696074, err_ate(s) 0.634303127604679
# =================================================================
# Iter: 1000
# Train: pehe 2.8704906552464244, err_ate 1.20179931838999, err_ate(s) 1.2017993183899895
# Test: pehe 2.6459354719055836, err_ate 1.0693613750700275, err_ate(s) 1.0693613750700275
# =================================================================
# Iter: 1200
# Train: pehe 2.742139371023651, err_ate 1.4807176872436185, err_ate(s) 1.4807176872436185
# Test: pehe 2.5491970956994137, err_ate 0.7203023689915766, err_ate(s) 0.7203023689915767
# =================================================================
# Iter: 1400
# Train: pehe 2.3811517753079476, err_ate 0.8349081157737948, err_ate(s) 0.8349081157737949
# Test: pehe 2.534929042561261, err_ate 0.4217474275328925, err_ate(s) 0.6521473988265262
# =================================================================
# Iter: 1600
# Train: pehe 2.397853284539999, err_ate 0.1262042232944547, err_ate(s) 0.7008191810973466
# Test: pehe 2.1984960744787956, err_ate 0.029964082990454166, err_ate(s) 0.28651269949643043
# =================================================================
# Iter: 1800
# Train: pehe 2.2541956491699637, err_ate 0.14207744788070298, err_ate(s) 0.4250779387780012
# Test: pehe 2.247564019911867, err_ate 0.13430743032293946, err_ate(s) 0.43452230289418187
# =================================================================
# Last result of replicate #6
# Train: pehe 2.2249300192692774, err_ate 0.03313133824308512, err_ate(s) 0.3621597602146845
# Test: pehe 2.4013923610689445, err_ate 0.38756012920724014, err_ate(s) 0.6278934822388667
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 3,  Replicate #7 *****
# ***************************************
# Iter: 0
# Train: pehe 4.8259113777554425, err_ate 1.3983797698941403, err_ate(s) 1.3983797698941405
# Test: pehe 4.486013992520659, err_ate 0.23765603012987602, err_ate(s) 0.6622898100916859
# =================================================================
# Iter: 200
# Train: pehe 3.4670317523820047, err_ate 0.27088031556845427, err_ate(s) 0.8259869514807531
# Test: pehe 3.470093631675375, err_ate 0.013951584024420205, err_ate(s) 0.459500654975018
# =================================================================
# Iter: 400
# Train: pehe 2.6514624176036605, err_ate 0.11083122825482783, err_ate(s) 0.4072527514659941
# Test: pehe 3.1174385578900488, err_ate 0.4567968616605347, err_ate(s) 1.3295510647141346
# =================================================================
# Iter: 600
# Train: pehe 2.431547927738657, err_ate 0.1637935002730222, err_ate(s) 0.7737236961699342
# Test: pehe 2.4535948326841317, err_ate 0.1497408278761625, err_ate(s) 0.4826872115606835
# =================================================================
# Iter: 800
# Train: pehe 2.4509290896938385, err_ate 0.99575614595553, err_ate(s) 0.9957561459555301
# Test: pehe 2.400944770786051, err_ate 0.35125695887321773, err_ate(s) 0.609599038957443
# =================================================================
# Iter: 1000
# Train: pehe 2.2882506449267264, err_ate 0.9735195080772969, err_ate(s) 0.9735195080772966
# Test: pehe 2.268780196712986, err_ate 0.030680265548940433, err_ate(s) 0.5936152757242211
# =================================================================
# Iter: 1200
# Train: pehe 2.175414072610009, err_ate 0.13764295844128416, err_ate(s) 0.5426307803421684
# Test: pehe 2.3862813397573497, err_ate 0.37295741072894506, err_ate(s) 0.8642498906597854
# =================================================================
# Iter: 1400
# Train: pehe 2.353787687207129, err_ate 0.27106978576242224, err_ate(s) 1.0189605097129413
# Test: pehe 2.1055649092781694, err_ate 0.04124084285760454, err_ate(s) 0.11328947137556782
# =================================================================
# Iter: 1600
# Train: pehe 2.1836100887853163, err_ate 0.3035468198522002, err_ate(s) 0.41430204171980095
# Test: pehe 2.304271350837657, err_ate 0.7608711334064959, err_ate(s) 0.7608711334064963
# =================================================================
# Iter: 1800
# Train: pehe 2.1948584783568625, err_ate 0.9313646976735128, err_ate(s) 0.9313646976735125
# Test: pehe 2.146405518551806, err_ate 0.19388037906320932, err_ate(s) 0.553954261780203
# =================================================================
# Last result of replicate #7
# Train: pehe 2.3712144994530795, err_ate 0.5975106539538431, err_ate(s) 1.010411002674558
# Test: pehe 2.078507496346437, err_ate 0.1032182424386705, err_ate(s) 0.32266363806911924
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 3,  Replicate #8 *****
# ***************************************
# Iter: 0
# Train: pehe 5.487377438932473, err_ate 1.9586374144812637, err_ate(s) 1.9586374144812642
# Test: pehe 4.565235477206029, err_ate 0.8896708849397359, err_ate(s) 0.8896708849397356
# =================================================================
# Iter: 200
# Train: pehe 3.569672322856106, err_ate 0.6701091154972931, err_ate(s) 1.0532163181546246
# Test: pehe 3.461817634483724, err_ate 0.33162673471809456, err_ate(s) 0.33162673471809445
# =================================================================
# Iter: 400
# Train: pehe 3.0444380040410635, err_ate 0.274339788450776, err_ate(s) 0.8165539573172665
# Test: pehe 3.03121615144014, err_ate 0.6390357005810297, err_ate(s) 0.6390357005810298
# =================================================================
# Iter: 600
# Train: pehe 2.7549926715328734, err_ate 1.1206578175167028, err_ate(s) 1.1206578175167028
# Test: pehe 2.766073727436741, err_ate 0.05182361949012937, err_ate(s) 0.713745059572554
# =================================================================
# Iter: 800
# Train: pehe 2.2923407322346794, err_ate 0.10452789723274947, err_ate(s) 0.47388769210804654
# Test: pehe 2.6412054557946836, err_ate 0.7612484613408432, err_ate(s) 0.7612484613408429
# =================================================================
# Iter: 1000
# Train: pehe 2.447034791997037, err_ate 0.3611013179891027, err_ate(s) 0.8048595026485558
# Test: pehe 2.377476785843749, err_ate 0.2165834813798907, err_ate(s) 0.23729490243973625
# =================================================================
# Iter: 1200
# Train: pehe 2.3460052183257334, err_ate 0.561511988149108, err_ate(s) 0.5615119881491084
# Test: pehe 2.5735790660008324, err_ate 0.47048315440308075, err_ate(s) 0.6893346005327047
# =================================================================
# Iter: 1400
# Train: pehe 2.232257852803553, err_ate 0.46738869616784484, err_ate(s) 0.4673886961678449
# Test: pehe 2.379853129639565, err_ate 0.23813647208936417, err_ate(s) 0.4588310170348893
# =================================================================
# Iter: 1600
# Train: pehe 2.3741686608124497, err_ate 0.5183811543320833, err_ate(s) 0.775684629680506
# Test: pehe 2.8980777996477207, err_ate 1.6502055420436201, err_ate(s) 1.6502055420436201
# =================================================================
# Iter: 1800
# Train: pehe 2.0509539691815024, err_ate 0.39460212823601726, err_ate(s) 0.6190896582188449
# Test: pehe 2.223768327564008, err_ate 0.22682012013050312, err_ate(s) 0.31154452790813897
# =================================================================
# Last result of replicate #8
# Train: pehe 2.0316719744600453, err_ate 0.10681310197315774, err_ate(s) 0.21666930779417978
# Test: pehe 2.329385149826568, err_ate 0.15642261698810322, err_ate(s) 0.6666122750710985
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 3,  Replicate #9 *****
# ***************************************
# Iter: 0
# Train: pehe 5.127922113469257, err_ate 0.8979411950000927, err_ate(s) 0.8979411950000925
# Test: pehe 4.691785177461214, err_ate 0.9528420004977876, err_ate(s) 0.9528420004977876
# =================================================================
# Iter: 200
# Train: pehe 4.576927232241449, err_ate 1.3593952067809743, err_ate(s) 1.3593952067809745
# Test: pehe 4.302041489279992, err_ate 2.1204667105916326, err_ate(s) 2.1204667105916326
# =================================================================
# Iter: 400
# Train: pehe 3.441417888816385, err_ate 1.3162444572267376, err_ate(s) 1.316244457226738
# Test: pehe 3.2229433206737834, err_ate 1.23831732052813, err_ate(s) 1.23831732052813
# =================================================================
# Iter: 600
# Train: pehe 3.5146725571591997, err_ate 1.81035861244971, err_ate(s) 1.8103586124497102
# Test: pehe 3.099923124864914, err_ate 1.4011532152829074, err_ate(s) 1.4011532152829076
# =================================================================
# Iter: 800
# Train: pehe 2.735509677577268, err_ate 0.34300128868545654, err_ate(s) 0.3430012886854563
# Test: pehe 2.6957664910787904, err_ate 0.7579514436611173, err_ate(s) 0.7579514436611174
# =================================================================
# Iter: 1000
# Train: pehe 3.146353619289924, err_ate 1.6175496738769057, err_ate(s) 1.617549673876906
# Test: pehe 3.289748206904187, err_ate 2.147591217357327, err_ate(s) 2.147591217357327
# =================================================================
# Iter: 1200
# Train: pehe 2.9993246661578494, err_ate 1.2245627150056206, err_ate(s) 1.2245627150056209
# Test: pehe 2.5563918089966173, err_ate 0.26100073294951176, err_ate(s) 0.554046675094888
# =================================================================
# Iter: 1400
# Train: pehe 2.7233163664003266, err_ate 0.34983134516750225, err_ate(s) 0.7761775391276028
# Test: pehe 2.692517509155615, err_ate 0.9192659808905289, err_ate(s) 0.9350931432723506
# =================================================================
# Iter: 1600
# Train: pehe 2.8032627389213087, err_ate 0.6973406031099404, err_ate(s) 0.6973406031099404
# Test: pehe 2.7950037240456234, err_ate 1.2678684853667566, err_ate(s) 1.2678684853667566
# =================================================================
# Iter: 1800
# Train: pehe 2.647552050997717, err_ate 0.07165969762876087, err_ate(s) 0.4398646651796718
# Test: pehe 2.3947405628759695, err_ate 0.1975289777492485, err_ate(s) 0.3329028771878602
# =================================================================
# Last result of replicate #9
# Train: pehe 2.7470579944981015, err_ate 0.8132364805159414, err_ate(s) 0.8228590617577803
# Test: pehe 2.4119264862003695, err_ate 0.09515012248628074, err_ate(s) 0.3311612751114259
# =================================================================
# Do not use one-hot encoding, d_x = 20
# ***************************************
# ***** n_source 3,  Replicate #10 *****
# ***************************************
# Iter: 0
# Train: pehe 5.510661207506827, err_ate 2.9218097441879123, err_ate(s) 2.9218097441879123
# Test: pehe 4.494596375766299, err_ate 0.6627639209465828, err_ate(s) 0.6627639209465829
# =================================================================
# Iter: 200
# Train: pehe 3.4914435614449526, err_ate 0.30667035972205703, err_ate(s) 1.0421416487512418
# Test: pehe 3.4972553081049713, err_ate 0.8901326341861295, err_ate(s) 0.8901326341861296
# =================================================================
# Iter: 400
# Train: pehe 3.0516887576737015, err_ate 0.6942641541845807, err_ate(s) 0.800140271218028
# Test: pehe 3.1449975442010323, err_ate 0.33761508091361336, err_ate(s) 0.39513196587951427
# =================================================================
# Iter: 600
# Train: pehe 2.9255185537081583, err_ate 0.06404928242039754, err_ate(s) 1.1300135062450236
# Test: pehe 2.7554863008522643, err_ate 0.2193619574585819, err_ate(s) 0.23895521861855962
# =================================================================
# Iter: 800
# Train: pehe 2.5172439663028254, err_ate 0.2311808302514542, err_ate(s) 0.23341307775273212
# Test: pehe 2.5786509593294964, err_ate 0.04566207109998477, err_ate(s) 0.5998768730297287
# =================================================================
# Iter: 1000
# Train: pehe 2.4058468328922658, err_ate 0.5921636612726042, err_ate(s) 0.5921636612726046
# Test: pehe 2.5712849704198173, err_ate 0.07211933428345407, err_ate(s) 0.4434098795706643
# =================================================================
# Iter: 1200
# Train: pehe 2.4044905720271514, err_ate 0.38397216240692056, err_ate(s) 0.3839721624069206
# Test: pehe 2.5443028861668515, err_ate 0.18178324164447357, err_ate(s) 0.4575182410041094
# =================================================================
# Iter: 1400
# Train: pehe 2.3823826825126546, err_ate 0.6995473051580576, err_ate(s) 0.6995473051580582
# Test: pehe 2.3804587291972146, err_ate 0.26745623467340507, err_ate(s) 0.3704633130350186
# =================================================================
# Iter: 1600
# Train: pehe 2.418819648789604, err_ate 0.30872604141505655, err_ate(s) 0.49937208948672457
# Test: pehe 2.4575525810653853, err_ate 0.1600374730226839, err_ate(s) 0.5105031937487489
# =================================================================
# Iter: 1800
# Train: pehe 2.422482741398727, err_ate 0.7800857038907419, err_ate(s) 0.7800857038907415
# Test: pehe 2.457494914292453, err_ate 0.7709727037316187, err_ate(s) 0.7709727037316189
# =================================================================
# Last result of replicate #10
# Train: pehe 2.4324560766537306, err_ate 0.5287238473184117, err_ate(s) 0.9283598191851441
# Test: pehe 2.353038469427331, err_ate 0.22733621999641151, err_ate(s) 0.32847250322337757
# =================================================================
# PERFORMANCE, n_sources 3
# Train: [2.45469587 0.41131637 0.7173028 ] [0.10651842 0.09083387 0.09064152]
# Test: [2.333921   0.19184803 0.45498503] [0.07383175 0.04794254 0.06488076]

# %%
stats_test_federated_mean = np.asarray([np.mean(stats_test_all,axis=0) for stats_test_all in stats_federated])
stats_test_federated_stderr = np.asarray([stats.sem(stats_test_all,axis=0) for stats_test_all in stats_federated])
np.savez('save_outputs/save_data1/stats_errors_test_federated.npz',
         stats_test_federated_mean=stats_test_federated_mean,
         stats_test_federated_stderr=stats_test_federated_stderr)
stats_test_federated_mean
# Out:
# array([[3.73035725, 0.60851888, 0.60851888],
#        [2.84335048, 0.42925107, 0.5866065 ],
#        [2.333921  , 0.19184803, 0.45498503]])

# %%
stats_test_federated_stderr
# Out:
# array([[0.06442256, 0.16014661, 0.16014661],
#        [0.09081823, 0.09088489, 0.0797915 ],
#        [0.07383175, 0.04794254, 0.06488076]])
